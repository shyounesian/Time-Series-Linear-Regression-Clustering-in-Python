# %% [markdown]
# ## Contents:
# ### Importing Libs
# ### Importing Dataset
# ### Finding Missing Values
# ### Renaming Columns
# ### Finding mixed-type Data
# ### Finding Duplicates
# ### Drop Column
# ### Data Consistency
# ### Extracting New values & Adding New Columns
# ### Exporting Dataset

# %% [markdown]
# ## Importing Libs

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Importing Dataset

# %%
path = r'C:\Users\shyou\OneDrive\Documents\Data Analitics Course\Achievement6\Exercise1'

# %%
df = pd.read_csv(os.path.join(path,'GlobalSuperstore.csv'))

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date       ship_mode customer_id   segment  \
# 0       1  MX-2014-143658   2/10/2014  Standard Class    SC-20575  Consumer
# 1       2  MX-2012-155047  15-10-2012  Standard Class    KW-16570  Consumer
# 2       3  MX-2012-155047  15-10-2012  Standard Class    KW-16570  Consumer
# 3       4  MX-2012-155047  15-10-2012  Standard Class    KW-16570  Consumer
# 4       5  MX-2012-155047  15-10-2012  Standard Class    KW-16570  Consumer
#
#             city             state   country market       product_id  \
# 0    Mexico City  Distrito Federal    Mexico  LATAM  OFF-LA-10002782
# 1  Dos Quebradas         Risaralda  Colombia  LATAM  FUR-FU-10004015
# 2  Dos Quebradas         Risaralda  Colombia  LATAM  FUR-BO-10002352
# 3  Dos Quebradas         Risaralda  Colombia  LATAM  OFF-BI-10004428
# 4  Dos Quebradas         Risaralda  Colombia  LATAM  OFF-AR-10004594
#
#           category Sub_category                        Product Name   sales  \
# ...

# %%
df.shape
# Out:
# (51290, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         51290 non-null  int64
#  1   Order ID       51290 non-null  object
#  2   Order Date     51290 non-null  object
#  3   ship_mode      51290 non-null  object
#  4   customer_id    51290 non-null  object
#  5   segment        51290 non-null  object
#  6   city           51290 non-null  object
#  7   state          51290 non-null  object
#  8   country        51290 non-null  object
#  9   market         51290 non-null  object
#  10  product_id     51290 non-null  object
#  11  category       51290 non-null  object
#  12  Sub_category   51290 non-null  object
#  13  Product Name   51290 non-null  object
#  14  sales          51290 non-null  float64
#  15  quantity       51290 non-null  int64
#  16  discount       51290 non-null  float64
# ...

# %%
df.describe()
# Out:
#             Row ID         sales      quantity      discount        profit  \
# count  51290.00000  51290.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000    246.490581      3.476545      0.142908     28.610982
# std    14806.29199    487.565361      2.278766      0.212280    174.340972
# min        1.00000      0.444000      1.000000      0.000000  -6599.978000
# 25%    12823.25000     30.758625      2.000000      0.000000      0.000000
# 50%    25645.50000     85.053000      3.000000      0.000000      9.240000
# 75%    38467.75000    251.053200      5.000000      0.200000     36.810000
# max    51290.00000  22638.480000     14.000000      0.850000   8399.976000
#
#        shipping_cost
# count   51290.000000
# mean       26.375915
# std        57.296804
# min         0.000000
# 25%         2.610000
# 50%         7.790000
# 75%        24.450000
# max       933.570000

# %% [markdown]
# ## Finding missing values

# %%
df['country'].value_counts(dropna = False)
# Out:
# United States    9994
# Australia        2837
# France           2827
# Mexico           2644
# Germany          2065
#                  ...
# South Sudan         2
# Burundi             2
# Bahrain             2
# Chad                2
# Eritrea             2
# Name: country, Length: 147, dtype: int64

# %%
df.isnull().sum()
# Out:
# id               0
# order_id         0
# order_date       0
# ship_mode        0
# customer_id      0
# segment          0
# city             0
# state            0
# country          0
# market           0
# product_id       0
# category         0
# Sub_category     0
# Product Name     0
# sales            0
# quantity         0
# discount         0
# profit           0
# shipping_cost    0
# dtype: int64

# %%
df_nan = df.loc[df['market'].isnull() == True]

# %%
df_nan
# Out:
# Empty DataFrame
# Columns: [id, order_id, order_date, ship_mode, customer_id, segment, city, state, country, market, product_id, category, Sub_category, Product Name, sales, quantity, discount, profit, shipping_cost]
# Index: []

# %% [markdown]
# ## Renaming columns

# %%
df.rename(columns = {'Row ID': 'id'}, inplace = True)

# %%
dict = {'Order ID': 'order_id' ,'Order Date': 'order_date'}
df.rename(columns = dict, inplace = True)

# %%
df
# Out:
#           id        order_id  order_date       ship_mode customer_id  \
# 0          1  MX-2014-143658   2/10/2014  Standard Class    SC-20575
# 1          2  MX-2012-155047  15-10-2012  Standard Class    KW-16570
# 2          3  MX-2012-155047  15-10-2012  Standard Class    KW-16570
# 3          4  MX-2012-155047  15-10-2012  Standard Class    KW-16570
# 4          5  MX-2012-155047  15-10-2012  Standard Class    KW-16570
# ...      ...             ...         ...             ...         ...
# 51285  51286    HU-2012-7730    5/9/2012     First Class     NF-8385
# 51286  51287    HU-2012-7730    5/9/2012     First Class     NF-8385
# 51287  51288    HU-2012-7730    5/9/2012     First Class     NF-8385
# 51288  51289    HU-2012-7730    5/9/2012     First Class     NF-8385
# 51289  51290    IZ-2011-5750  25-08-2011  Standard Class    SZ-10035
#
#            segment           city             state   country market  \
# ...

# %% [markdown]
# ## Finding mixed-type data

# %%
for col in df.columns.tolist():
  weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)

# %%
## There is no mixed-type data in dateset

# %% [markdown]
# ## Finding Duplicates

# %%
df_dups = df[df.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [id, order_id, order_date, ship_mode, customer_id, segment, city, state, country, market, product_id, category, Sub_category, Product Name, sales, quantity, discount, profit, shipping_cost]
# Index: []

# %% [markdown]
# ## Drop Column

# %%
df.drop(['Product Name'], axis=1 , inplace=True)

# %%
df
# Out:
#           id        order_id  order_date       ship_mode customer_id  \
# 0          1  MX-2014-143658   2/10/2014  Standard Class    SC-20575
# 1          2  MX-2012-155047  15-10-2012  Standard Class    KW-16570
# 2          3  MX-2012-155047  15-10-2012  Standard Class    KW-16570
# 3          4  MX-2012-155047  15-10-2012  Standard Class    KW-16570
# 4          5  MX-2012-155047  15-10-2012  Standard Class    KW-16570
# ...      ...             ...         ...             ...         ...
# 51285  51286    HU-2012-7730    5/9/2012     First Class     NF-8385
# 51286  51287    HU-2012-7730    5/9/2012     First Class     NF-8385
# 51287  51288    HU-2012-7730    5/9/2012     First Class     NF-8385
# 51288  51289    HU-2012-7730    5/9/2012     First Class     NF-8385
# 51289  51290    IZ-2011-5750  25-08-2011  Standard Class    SZ-10035
#
#            segment           city             state   country market  \
# ...

# %% [markdown]
# ## Data Consistency

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
# Out:
# C:\Users\shyou\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\shyou\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-09-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\shyou\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24-09-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
df['order_date']
# Out:
# 0       2014-02-10
# 1       2012-10-15
# 2       2012-10-15
# 3       2012-10-15
# 4       2012-10-15
#            ...
# 51285   2012-05-09
# 51286   2012-05-09
# 51287   2012-05-09
# 51288   2012-05-09
# 51289   2011-08-25
# Name: order_date, Length: 51290, dtype: datetime64[ns]

# %%
df['order_date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 51290 entries, 0 to 51289
# Series name: order_date
# Non-Null Count  Dtype
# --------------  -----
# 51290 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 400.8 KB

# %% [markdown]
# ## Extracting year and month from order_date and Creating new columns

# %%
df['year'], df['month'] = df['order_date'].dt.year, df['order_date'].dt.month

# %%
df
# Out:
#           id        order_id order_date       ship_mode customer_id  \
# 0          1  MX-2014-143658 2014-02-10  Standard Class    SC-20575
# 1          2  MX-2012-155047 2012-10-15  Standard Class    KW-16570
# 2          3  MX-2012-155047 2012-10-15  Standard Class    KW-16570
# 3          4  MX-2012-155047 2012-10-15  Standard Class    KW-16570
# 4          5  MX-2012-155047 2012-10-15  Standard Class    KW-16570
# ...      ...             ...        ...             ...         ...
# 51285  51286    HU-2012-7730 2012-05-09     First Class     NF-8385
# 51286  51287    HU-2012-7730 2012-05-09     First Class     NF-8385
# 51287  51288    HU-2012-7730 2012-05-09     First Class     NF-8385
# 51288  51289    HU-2012-7730 2012-05-09     First Class     NF-8385
# 51289  51290    IZ-2011-5750 2011-08-25  Standard Class    SZ-10035
#
#            segment           city             state   country market  \
# 0         Consumer    Mexico City  Distrito Federal    Mexico  LATAM
# ...

# %% [markdown]
# ## Exporting dataset

# %%
df.to_csv(os.path.join(path, 'GlobalSuperstore_clean.csv'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             51290 non-null  int64
#  1   order_id       51290 non-null  object
#  2   order_date     51290 non-null  datetime64[ns]
#  3   ship_mode      51290 non-null  object
#  4   customer_id    51290 non-null  object
#  5   segment        51290 non-null  object
#  6   city           51290 non-null  object
#  7   state          51290 non-null  object
#  8   country        51290 non-null  object
#  9   market         51290 non-null  object
#  10  product_id     51290 non-null  object
#  11  category       51290 non-null  object
#  12  Sub_category   51290 non-null  object
#  13  sales          51290 non-null  float64
#  14  quantity       51290 non-null  int64
#  15  discount       51290 non-null  float64
#  16  profit         51290 non-null  float64
# ...
